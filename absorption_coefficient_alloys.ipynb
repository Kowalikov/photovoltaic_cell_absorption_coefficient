# %% [markdown]
# ## Imports:

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import scipy.special as special

# %% [markdown]
# ### Parameters:

# %%
# ---- constants ----
# all in electronovolts
h = 4.135667696e-15
h_bar = 6.582119569e-16 #eV*s
m_0 = 5.686e-12 #eV*s/A^2
J_to_eV = 1
alpha_f = 1/137.036

# # all in Si
# h = 6.626e-34
# h_bar = 1.054571e-34
# m_0 = 9.109383e-31

eV_to_J = 1.602176e-19
J_to_eV = 1/eV_to_J
h_bar2_2m = 3.81e-20 #ev*Angstr.^2

# %% [markdown]
# ##### AlSb:

# %%
class AlSb:
    # Define the material parameters
    a_lc = 6.1355e-10
    E_g = 2.386 # Bandgap energy
    E_p = 18.7#*eV_to_J
    #P_cv = h_bar*np.sqrt(E_p/(2*m_0))
    P_cv = np.sqrt(E_p*h_bar2_2m)
    exper_alpha_upscaling = 1. # CHANGE !!! ADJUST

    F = -0.56
    delta_so = 0.676

    # Define the spin-orbit coupling constants
    gamma_1 = 5.18
    gamma_2 = 1.19
    gamma_3 = 1.97

    # optical parameters:
    epsilon_r = 19.58
    n_r = np.sqrt(epsilon_r)

    def __init__(self):
        pass

# %% [markdown]
# ##### GaSb:

# %%
class GaSb:
    
    # Define the material parameters
    a_lc = 6.0959e-10
    E_g = 0.812 # Bandgap energy
    E_p = 25.8#*eV_to_J
    #P_cv = h_bar*np.sqrt(E_p/(2*m_0))
    P_cv = np.sqrt(E_p*h_bar2_2m)
    exper_alpha_upscaling = 1.35

    F = -1.
    delta_so = 0.76

    # Define the spin-orbit coupling constants
    gamma_1 = 13.4
    gamma_2 = 4.7
    gamma_3 = 6.
    
    # optical parameters:
    epsilon_r = 15.78
    n_r = np.sqrt(epsilon_r)

    def __init__(self):
        pass

# %% [markdown]
# ##### Ga0.57Al0.43Sb

# %%
gasb = GaSb()
alsb = AlSb()

# %%
gasb.E_g = np.array([gasb.E_g+gasb.delta_so,gasb.E_g,gasb.E_g])
gasb.E_g
# Out:
# array([1.572, 0.812, 0.812])

# %%
# optical parameters:
gasb.epsilon_r = np.array([19.65,15.78,15.78])
gasb.n_r = np.sqrt(gasb.epsilon_r)

# %%
alsb.E_g = np.array([alsb.E_g+alsb.delta_so,alsb.E_g,alsb.E_g])
alsb.E_g
# Out:
# array([3.062, 2.386, 2.386])

# %%
# optical parameters:
alsb.epsilon_r = np.array([18.6,19.58,19.58])
alsb.n_r = np.sqrt(alsb.epsilon_r)

# %%
# optical parameters:
epsilon_r = x*(gasb.epsilon_r-alsb.epsilon_r)+alsb.epsilon_r # CHANGE !!! ADJUST
n_r = np.sqrt(epsilon_r)
n_r, epsilon_r
# Out:
# (array([4.3648024 , 4.23627195, 4.23627195]),
#  array([19.0515, 17.946 , 17.946 ]))

# %%
# bowing parameters:
bow_E_g = [-0.044,1.22]
bow_delta_so = 0.3
x = 0.43

# Define the material parameters
a_lc = x*alsb.a_lc+(1-x)*gasb.a_lc
E_g = x*alsb.E_g+(1-x)*gasb.E_g-x*(1-x)*(bow_E_g[0]+bow_E_g[1]*x) # Bandgap energy
E_p = x*alsb.E_p+(1-x)*gasb.E_p#*eV_to_J
#P_cv = h_bar*np.sqrt(E_p/(2*m_0)) # zmienić na formułę z h_bar2_2m
P_cv = np.sqrt(E_p*h_bar2_2m)
exper_alpha_upscaling = x*alsb.exper_alpha_upscaling+(1-x)*gasb.exper_alpha_upscaling # CHANGE !!! ADJUST

F = x*alsb.F+(1-x)*gasb.F
delta_so = x*alsb.delta_so+(1-x)*gasb.delta_so-x*(1-x)*bow_delta_so

# Define the spin-orbit coupling constants
gamma_1 = x*alsb.gamma_1+(1-x)*gasb.gamma_1
gamma_2 = x*alsb.gamma_2+(1-x)*gasb.gamma_2
gamma_3 = x*alsb.gamma_3+(1-x)*gasb.gamma_3

# %% [markdown]
# ### Abs coeff:

# %%
def calc_absorption_coeff(hw):
    """k needs to be in angstrems

    Args:
        k (_type_): _description_

    Returns:
        _type_: _description_
    """
    def norm_sec(x, del_l=0.01):
        y = 1/(np.pi*del_l*np.cosh(x/del_l))

        return y
    
    def integrand(kx, ky, kz, hw):
        # Define the 8x8 Hamiltonian matrix
        H = np.zeros((4,4), dtype=np.complex128)
        
        # with conversion of values from p. 189 
        # file:///D:/Nauka/in%C5%BCynierka/bands-and-photons-in-iii-
        # v-semiconductor-quantum-structures-0198767277-9780198767275_compress.pdf
        
        # Fill in the off-diagonal elements of the Hamiltonian
        inter = (h_bar/m_0*P_cv*1e1)**2
        inter += (h_bar/m_0*P_cv*1e1)**2
        inter += (h_bar/m_0*P_cv*1e1)**2
        
        E_ck = E_g[-1]/2+np.sqrt(E_g[-1]**2/4+h_bar2_2m*2/3*E_p*np.dot([kx, ky, kz],[kx, ky, kz]))
        E_vk = 0
        inter = inter*hw/(E_ck-E_vk)**2*norm_sec(E_ck-E_vk-hw)
        
        return inter

    k_top = 0.2*2*np.pi/a_lc#/1e10
    #I, err = integrate.tplquad(integrand, 0., k_top, 0., k_top, 0., k_top, args=([hw]))
    
    n_bins = 40
    dk = k_top/n_bins

    k_bins = np.linspace(0, k_top, n_bins+1)
    k_vals = (k_bins[:-1]+k_bins[1:])/2
    I = 0.
    for x_i in range(n_bins):
        for y_i in range(n_bins):
            for z_i in range(n_bins):
                I+=integrand(k_vals[x_i],
                          k_vals[y_i],
                          k_vals[z_i],
                          hw)
    I = I*dk**3
    
    alpha = alpha_f/(2*np.pi*n_r[-1])*I
    
    return alpha


points = 50
alphas = np.zeros((points))
hw_range = np.linspace(1.4,
                       2.0,
                       points)
for i, hw in enumerate(hw_range):
    alphas[i] = calc_absorption_coeff(hw)


alphas = alphas*10000

# %%
with plt.style.context('bmh'):
    plt.plot(hw_range, alphas)
    plt.show()

# %% [markdown]
# ## Abs coeff from 8kp band diagrams (0_.4pi range):

# %%
# calculation parameters:
k_top = 0.2
points = 50

# %% [markdown]
# #### Load band diagrams:

# %%
bands = np.load(f'./results/Al0.43Ga0.57Sb_300k_8kp_no-strain_{points}points_top{k_top}.npy')
str_bands = np.load(f'./results/Al0.43Ga0.57Sb_300k_8kp_strain-0.0027855718241732385_{points}points_top{k_top}.npy')

# %%
for i in range(4):
    plt.plot(str_bands[i,0,0,:])
for i in range(4):
    plt.plot(bands[i,0,0,:], '-.')
plt.show()

# %% [markdown]
# #### Calc abs. coeff.:

# %%
def calc_absorption_coeff(bands, hw, k_top=0.2, points=50, del_l=0.005):
    """k needs to be in angstrems

    Args:
        k (_type_): _description_

    Returns:
        _type_: _description_
    """
    def norm_sec(x, del_l=0.005):
        y = 1/(np.pi*del_l*np.cosh(x/del_l))

        return y
    
    def integrand(kx, ky, kz, hw, E_ck, E_vk):
        # Define the 8x8 Hamiltonian matrix
        H = np.zeros((4,4), dtype=np.complex128)
        
        # with conversion of values from p. 189 
        # file:///D:/Nauka/in%C5%BCynierka/bands-and-photons-in-iii-
        # v-semiconductor-quantum-structures-0198767277-9780198767275_compress.pdf
        
        # Fill in the off-diagonal elements of the Hamiltonian
        inter = (h_bar/m_0*P_cv)**2
        inter += (h_bar/m_0*P_cv)**2
        inter += (h_bar/m_0*P_cv)**2
        
        inter = inter*hw/(E_ck-E_vk)**2*norm_sec(E_ck-E_vk-hw, del_l=del_l)
        
        return inter

    k_lim = k_top*2*np.pi/a_lc
    #I, err = integrate.tplquad(integrand, 0., k_lim, 0., k_lim, 0., k_lim, args=([hw]))
    
    n_bins = points
    dk = k_lim/n_bins

    k_bins = np.linspace(0, k_lim, n_bins)
    k_vals = k_bins
    I = np.array([0,0,0], dtype=np.float64)
    valence_indices = [0,1,2]
    for v_i in valence_indices:
        for x_i in range(n_bins):
            #print(f'Valence band [{v_i+1}/{len(valence_indices)}], [{x_i+1}/{n_bins}]', end='\r')
            for y_i in range(n_bins):
                for z_i in range(n_bins):
                    I[v_i]+=integrand(k_vals[x_i],
                            k_vals[y_i],
                            k_vals[z_i],
                            hw,
                            bands[3,x_i,y_i,z_i],
                            bands[v_i,x_i,y_i,z_i]
                            )
    I = I*dk**3
    
    alpha = np.array([0,0,0], dtype=np.float64)
    for band_i in range(3):
        alpha[band_i] = alpha_f/(2*np.pi*n_r[band_i])*I[band_i]
    
    return alpha

# %%
hw_points = 20
valence_bands = 3
alphas = np.zeros((hw_points,valence_bands))
hw_range = np.linspace(1.2,
                       2.2,
                       hw_points)
for i, hw in enumerate(hw_range):
    print(f'[{i+1}/{hw_points}]', end='\r')
    alphas[i] = calc_absorption_coeff(bands, hw, k_top, points)
    
alphas = alphas*exper_alpha_upscaling*10000*12
# Out:
# [20/20]

# %%
with plt.style.context('bmh'):
    fig, axs = plt.subplots(1,2, figsize=(12,4.5))
    labels = ['Vso->C','Vlh->C','Vhh->C',]
    for i in range(3):
        axs[0].plot(hw_range, alphas[:,i], label=labels[i])
    axs[0].legend()
    axs[1].plot(hw_range, alphas.sum(axis=1))
    
    axs[0].set_title('Abs. coeff from each band:')
    axs[1].set_title('Abs. coeff combined:')
    plt.show()

# %%
hw_points = 80
valence_bands = 3
str_alphas = np.zeros((hw_points,valence_bands))
hw_range = np.linspace(1.2,
                       2.2,
                       hw_points)
for i, hw in enumerate(hw_range):
    print(f'[{i+1}/{hw_points}]', end='\r')
    str_alphas[i] = calc_absorption_coeff(str_bands, hw, k_top, points)
    
str_alphas = str_alphas*exper_alpha_upscaling*10000*12
# Out:
# [80/80]

# %%
with plt.style.context('bmh'):
    fig, axs = plt.subplots(1,2, figsize=(12,4.5))
    labels = ['Vso->C','Vlh->C','Vhh->C',]
    for i in range(3):
        axs[0].plot(hw_range, str_alphas[:,i], label=labels[i])
    axs[0].legend()
    axs[1].plot(hw_range, str_alphas.sum(axis=1))
    
    axs[0].set_title('Abs. coeff from each band (with strains):')
    axs[1].set_title('Abs. coeff combined (with strains):')
    plt.show()

# %% [markdown]
# ## Abs coeff from 8kp band diagrams (pi range):

# %%
# calculation parameters:
k_top = 0.5
points = 100

# %% [markdown]
# #### Load band diagrams:

# %%
bands = np.load(f'./results/Al0.43Ga0.57Sb_300k_8kp_no-strain_{points}points_top{k_top}.npy')
str_bands = np.load(f'./results/Al0.43Ga0.57Sb_300k_8kp_strain-0.0027855718241732385_{points}points_top{k_top}.npy')

# %%
for i in range(4):
    bands_names = ['SO','LH','HH','CB']
    plt.plot(bands[i,0,0,:], label=bands_names[i])
plt.legend()
plt.show()

# %% [markdown]
# #### Calc abs. coeff.:

# %%
hw_points = 50
valence_bands = 3
alphas = np.zeros((hw_points,valence_bands))
hw_range = np.linspace(1.2,
                       2.2,
                       hw_points)
for i, hw in enumerate(hw_range):
    print(f'[{i+1}/{hw_points}]', end='\r')
    alphas[i] = calc_absorption_coeff(bands, hw, k_top, points, del_l=0.02)
    
alphas = alphas*exper_alpha_upscaling*10000*12
# Out:
# [50/50]

# %%
with plt.style.context('bmh'):
    fig, axs = plt.subplots(1,2, figsize=(12,4.5))
    labels = ['Vso->C','Vlh->C','Vhh->C',]
    for i in range(3):
        axs[0].plot(hw_range, alphas[:,i], label=labels[i])
    axs[0].legend()
    axs[1].plot(hw_range, alphas.sum(axis=1))
    
    axs[0].set_title('Abs. coeff from each band:')
    axs[1].set_title('Abs. coeff combined:')
    plt.show()

# %%
hw_points = 50
valence_bands = 3
str_alphas = np.zeros((hw_points,valence_bands))
hw_range = np.linspace(1.2,
                       2.2,
                       hw_points)
for i, hw in enumerate(hw_range):
    print(f'[{i+1}/{hw_points}]', end='\r')
    str_alphas[i] = calc_absorption_coeff(str_bands, hw, k_top, points, del_l=0.02)
    
str_alphas = str_alphas*exper_alpha_upscaling*10000*12
# Out:
# [50/50]

# %%
with plt.style.context('bmh'):
    fig, axs = plt.subplots(1,2, figsize=(12,4.5))
    labels = ['Vso->C','Vlh->C','Vhh->C',]
    for i in range(3):
        axs[0].plot(hw_range, str_alphas[:,i], label=labels[i])
    axs[0].legend()
    axs[1].plot(hw_range, str_alphas.sum(axis=1))
    
    axs[0].set_title('Abs. coeff from each band (with strains):')
    axs[1].set_title('Abs. coeff combined (with strains):')
    plt.show()
